# %%
import pandas as pd

# %%
data  = pd.read_csv("Trinity oljorok MAY 2024.csv", on_bad_lines='skip')

# %%
data
# Out:
#                               Unnamed: 0         Unnamed: 1  \
# 0                                    NaN                NaN
# 1                                    NaN                NaN
# 2                                    NaN                NaN
# 3                                    NaN                NaN
# 4                                    NaN                NaN
# ..                                   ...                ...
# 380                    Territory Manager                NaN
# 381  Reviewed By: ……………………………………………………..  Date: ………………...……
# 382                       Retail Manager                NaN
# 383   Confirmed By: ……………………………………………………  Date: ………………...……
# 384                    Credit Controller                NaN
#
#     TOTAL PURCHASES FOR THE MONTH Unnamed: 3                    Unnamed: 4  \
# 0                             NaN        NaN                           NaN
# 1                             NaN        NaN                           NaN
# ...

# %%
data1 = data.drop(data.index[:4])

# %%
data1
# Out:
#                               Unnamed: 0         Unnamed: 1  \
# 4                                    NaN                NaN
# 5                                    NaN                NaN
# 6                                    NaN                NaN
# 7                                    NaN                NaN
# 8                                    NaN                  1
# ..                                   ...                ...
# 380                    Territory Manager                NaN
# 381  Reviewed By: ……………………………………………………..  Date: ………………...……
# 382                       Retail Manager                NaN
# 383   Confirmed By: ……………………………………………………  Date: ………………...……
# 384                    Credit Controller                NaN
#
#     TOTAL PURCHASES FOR THE MONTH Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 4                            Date        NaN       Daily  Cumulative
# 5                             NaN        NaN  Pump Sales  Pump Sales
# ...

# %%
data2=data1.drop(data1.columns[:2], axis=1)

# %%
data2
# Out:
#     TOTAL PURCHASES FOR THE MONTH Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 4                            Date        NaN       Daily  Cumulative
# 5                             NaN        NaN  Pump Sales  Pump Sales
# 6                             NaN        NaN           A           B
# 7                        Product:        NaN       SUPER         NaN
# 8                           1-May        NaN         954         954
# ..                            ...        ...         ...         ...
# 380                           NaN        NaN         NaN         NaN
# 381                           NaN        NaN         NaN         NaN
# 382                           NaN        NaN         NaN         NaN
# 383                           NaN        NaN         NaN         NaN
# 384                           NaN        NaN         NaN         NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  ...  \
# ...

# %%
data3=data2.drop(data2.columns[1], axis=1)

# %%
data3
# Out:
#     TOTAL PURCHASES FOR THE MONTH  Unnamed: 4  Unnamed: 5 Unnamed: 6  \
# 4                            Date       Daily  Cumulative        NaN
# 5                             NaN  Pump Sales  Pump Sales        NaN
# 6                             NaN           A           B        NaN
# 7                        Product:       SUPER         NaN        NaN
# 8                           1-May         954         954        NaN
# ..                            ...         ...         ...        ...
# 380                           NaN         NaN         NaN        NaN
# 381                           NaN         NaN         NaN        NaN
# 382                           NaN         NaN         NaN        NaN
# 383                           NaN         NaN         NaN        NaN
# 384                           NaN         NaN         NaN        NaN
#
#     Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  ...  \
# ...

# %%
data4=data3.drop(data3.columns[3], axis=1)

# %%
data4
# Out:
#     TOTAL PURCHASES FOR THE MONTH  Unnamed: 4  Unnamed: 5 Unnamed: 7  \
# 4                            Date       Daily  Cumulative    Opening
# 5                             NaN  Pump Sales  Pump Sales        Dip
# 6                             NaN           A           B          C
# 7                        Product:       SUPER         NaN        NaN
# 8                           1-May         954         954       5739
# ..                            ...         ...         ...        ...
# 380                           NaN         NaN         NaN        NaN
# 381                           NaN         NaN         NaN        NaN
# 382                           NaN         NaN         NaN        NaN
# 383                           NaN         NaN         NaN        NaN
# 384                           NaN         NaN         NaN        NaN
#
#     Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# ...

# %%
data5=data4.drop(data4.columns[8], axis=1)

# %%
data5
# Out:
#     TOTAL PURCHASES FOR THE MONTH  Unnamed: 4  Unnamed: 5 Unnamed: 7  \
# 4                            Date       Daily  Cumulative    Opening
# 5                             NaN  Pump Sales  Pump Sales        Dip
# 6                             NaN           A           B          C
# 7                        Product:       SUPER         NaN        NaN
# 8                           1-May         954         954       5739
# ..                            ...         ...         ...        ...
# 380                           NaN         NaN         NaN        NaN
# 381                           NaN         NaN         NaN        NaN
# 382                           NaN         NaN         NaN        NaN
# 383                           NaN         NaN         NaN        NaN
# 384                           NaN         NaN         NaN        NaN
#
#     Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 13 Unnamed: 14  \
# ...

# %%
data6=data5.drop(data5.columns[10:], axis=1)

# %%
data6
# Out:
#     TOTAL PURCHASES FOR THE MONTH  Unnamed: 4  Unnamed: 5 Unnamed: 7  \
# 4                            Date       Daily  Cumulative    Opening
# 5                             NaN  Pump Sales  Pump Sales        Dip
# 6                             NaN           A           B          C
# 7                        Product:       SUPER         NaN        NaN
# 8                           1-May         954         954       5739
# ..                            ...         ...         ...        ...
# 380                           NaN         NaN         NaN        NaN
# 381                           NaN         NaN         NaN        NaN
# 382                           NaN         NaN         NaN        NaN
# 383                           NaN         NaN         NaN        NaN
# 384                           NaN         NaN         NaN        NaN
#
#     Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 13 Unnamed: 14
# ...

# %%
data7 = data6.drop(data6.index[2])

# %%
data7
# Out:
#     TOTAL PURCHASES FOR THE MONTH  Unnamed: 4  Unnamed: 5 Unnamed: 7  \
# 4                            Date       Daily  Cumulative    Opening
# 5                             NaN  Pump Sales  Pump Sales        Dip
# 7                        Product:       SUPER         NaN        NaN
# 8                           1-May         954         954       5739
# 9                           2-May        1006       1,960      4,764
# ..                            ...         ...         ...        ...
# 380                           NaN         NaN         NaN        NaN
# 381                           NaN         NaN         NaN        NaN
# 382                           NaN         NaN         NaN        NaN
# 383                           NaN         NaN         NaN        NaN
# 384                           NaN         NaN         NaN        NaN
#
#     Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 13 Unnamed: 14
# ...
